# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1=pd.read_csv('C://Users//Mahidhar babu//Desktop//Ineuron Notebook//No Show Appontments//2017.csv')

# %%
data1.head()
# Out:
#    especialidad  edad  sexo  reserva_mes_d  reserva_mes_c  reserva_dia_d  \
# 0            76    66     1              1           0.87              1
# 1            76    66     1              1           0.87              1
# 2            18    35     1              1           0.87              1
# 3            51    44     2              1           0.87              1
# 4            76    72     2              1           0.87              1
#
#    reserva_dia_c  reserva_hora_d  reserva_hora_c  creacion_mes_d  \
# 0           0.62              18            0.00              12
# 1           0.62              19            0.26              12
# 2           0.62              15           -0.71              12
# 3           0.62              19            0.26              11
# 4           0.62              12           -1.00              12
#
#    creacion_mes_c  creacion_dia_d  creacion_dia_c  creacion_hora_d  \
# ...

# %%
data2=pd.read_csv('C://Users//Mahidhar babu//Desktop//Ineuron Notebook//No Show Appontments//KaggleV2-May-2016.csv')

# %%
data2.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
data2.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
data2.drop(['Neighbourhood'],axis=1)
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age  Scholarship  Hipertension  Diabetes  \
# 0       2016-04-29T00:00:00Z   62            0             1         0
# ...

# %%
data2.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %%
data2.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
data2.Gender[data2.Gender == 'M']=1
data2.Gender[data2.Gender == 'F']=0
# Out:
# <ipython-input-10-ed0ea3bd86fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.Gender[data2.Gender == 'M']=1
# <ipython-input-10-ed0ea3bd86fe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.Gender[data2.Gender == 'F']=0

# %%
data2.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      0  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      1  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      0  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      0  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      0  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
#data2.No-show[data2.No-show == 'Yes'] = 1
#data2.No-show[data2.No-show == 'No'] = 0

# %%
data2.drop(['Neighbourhood'],axis=1)
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      0  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      1  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      0  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      0  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      0  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      0  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      0  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      0  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      0  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      0  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age  Scholarship  Hipertension  Diabetes  \
# 0       2016-04-29T00:00:00Z   62            0             1         0
# ...

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',data=data2)

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',hue='Gender',data=data2,palette='RdBu_r')

# %%
sns.distplot(data2['Age'].dropna(),kde=False,color='red',bins=10)

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',hue='Scholarship',data=data2,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',hue='Hipertension',data=data2,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',hue='Diabetes',data=data2,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',hue='Alcoholism',data=data2,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',hue='Handcap',data=data2,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='No-show',hue='SMS_received',data=data2,palette='RdBu_r')

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()
# 2/3. FIT AND TRANSFORM
# use df.apply() to apply le.fit_transform to all columns
df = data2.apply(le.fit_transform)
df.head(10)
# Out:
#    PatientId  AppointmentID  Gender  ScheduledDay  AppointmentDay  Age  \
# 0      30845          29332       0         27741               0   63
# 1      55325          29079       1         27503               0   57
# 2      15722          29115       0         27538               0   63
# 3       9018          29299       0         27708               0    9
# 4      23941          29073       0         27497               0   57
# 5      47043          21106       0         20073               0   77
# 6      57939          22503       0         21385               0   24
# 7      14326          22616       0         21495               0   40
# 8      37460          26344       0         24944               0   22
# 9      42680          21987       0         20894               0   20
#
#    Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  \
# 0             39            0             1         0           0        0
# ...

# %%
sns.heatmap(df)

# %%
corr = data2.corr()
ax = sns.heatmap(corr,vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(20, 220, n=200),square=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right')
# Out:
# [Text(0.5, 0, 'PatientId'),
#  Text(1.5, 0, 'AppointmentID'),
#  Text(2.5, 0, 'Age'),
#  Text(3.5, 0, 'Scholarship'),
#  Text(4.5, 0, 'Hipertension'),
#  Text(5.5, 0, 'Diabetes'),
#  Text(6.5, 0, 'Alcoholism'),
#  Text(7.5, 0, 'Handcap'),
#  Text(8.5, 0, 'SMS_received')]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('No-show',axis=1),df['No-show'],
                                                    test_size=0.30,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
accuracy=confusion_matrix(y_test,predictions)

# %%
accuracy
# Out:
# array([[26562,     0],
#        [ 6597,     0]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.8010494888265629
